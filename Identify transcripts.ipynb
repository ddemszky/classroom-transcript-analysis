# %%
import pandas as pd

# %%
data = pd.read_csv("data/transcript_metadata.csv")

# %%
transcripts = pd.read_csv("data/ncte_single_utterances.csv")

# %%
data.head()
# Out:
#    OBSID  year                                       student_text  \
# 0      3     1  C. Because 16 times 3 and 16 times 6, they bot...
# 1    141     1  North? Up. Compass. Yes. It's here. South. Wes...
# 2    452     1  Yep. The number, the oranges in four groups. I...
# 3   2198     2  [Inaudible comment]. Twenty-seven. Yep. Oh, we...
# 4   2531     2  320. [Inaudible] 320. Cause 4 times 8, it’s th...
#
#                                         teacher_text  \
# 0  Okay.  Math should be out.  Everything else, p...
# 1  Okay.  So today we're going to solve some addi...
# 2  Okay.  You have about five minutes to try to s...
# 3  Okay, I need everybody [sitting] right now.  O...
# 4  [Inaudible] either way, if you are finished cu...
#
#                                      student_cleaned  \
# 0  c because 16 times 3 and 16 times 6 they both ...
# 1  north up compass yes it s here south west east...
# 2  yep the number the oranges in four groups it s...
# 3  inaudible comment twenty seven yep oh we could...
# 4  320 inaudible 320 cause 4 times 8 it s the sam...
#
#                                      teacher_cleaned  NCTETID  DISTRICT  \
# 0  okay math should be out everything else please...    11024      11.0
# 1  okay so today we re going to solve some additi...    11024      11.0
# 2  okay you have about five minutes to try to sol...    11024      11.0
# 3  okay i need everybody sitting right now okay s...    11024      11.0
# 4  inaudible either way if you are finished cutti...    11024      11.0
#
#    CLASS_11  CLASS_12  ...  MALE    S_MALE   S_WHITE    S_AFAM    S_HISP  \
# 0       1.0       1.0  ...   1.0  0.500000  0.111111  0.055556  0.777778
# 1       1.0       1.0  ...   1.0  0.500000  0.111111  0.055556  0.777778
# 2       1.0       1.0  ...   1.0  0.500000  0.111111  0.055556  0.777778
# 3       1.0       1.0  ...   1.0  0.733333  0.000000  0.066667  0.933333
# 4       1.0       1.0  ...   1.0  0.733333  0.000000  0.066667  0.933333
#
#    S_ASIAN  S_RACE_OTHER    S_FRPL    S_SPED     S_LEP
# 0      0.0      0.055556  0.833333  0.000000  0.333333
# 1      0.0      0.055556  0.833333  0.000000  0.333333
# 2      0.0      0.055556  0.833333  0.000000  0.333333
# 3      0.0      0.000000  0.600000  0.266667  0.600000
# 4      0.0      0.000000  0.600000  0.266667  0.600000
#
# [5 rows x 128 columns]

# %%
data.sort_values("CLNC", ascending=False)[["OBSID", "CLNC"]]
# Out:
#       OBSID  CLNC
# 797    2136  6.00
# 291      72  5.00
# 1537   2602  4.75
# 1323    998  4.00
# 736     256  4.00
# ...     ...   ...
# 635    2379  1.00
# 1624   4456  1.00
# 368    1083   NaN
# 1320    994   NaN
# 1324   1141   NaN
#
# [1625 rows x 2 columns]

# %%
transcripts = pd.read_csv("data/ncte_single_utterances.csv")
